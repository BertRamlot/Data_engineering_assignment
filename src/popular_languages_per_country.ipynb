# %%
from sqlalchemy import create_engine, text
import pandas as pd

from stack_overflow_survey import StackOverflowSurvey

import os
if 'changed_dir' not in locals():
    changed_dir = True
    current_dir = os.getcwd()
    os.chdir("../")

# %%
user = "postgres"
password = "postgres"
db_name = "stackoverflow_survey_data"
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@localhost:5432/{db_name}')

# %%
# Load the data into the database
year = 2021
surveyData = StackOverflowSurvey()
survey_results_df = surveyData.get_all_data(year)
result = survey_results_df.to_sql(
    f"results_{year}",
    engine,
    index=False,
    if_exists="replace",
)
result
# Out:
# 381

# %%
# Execute the query that lists the number of developers by country for the top 3 programming languages
year = 2021
country_amount = 3
query = f"""
DO $$
DECLARE
    top_lang_column_definition_text text;
    sql_text text;
    _cursor CONSTANT refcursor := '_cursor';
BEGIN
    top_lang_column_definition_text := 
        '"Country" text, ' || (
            SELECT string_agg(quote_ident(prog_lang), ' bigint, ')
            FROM (
            SELECT unnest(string_to_array("LanguageHaveWorkedWith", ';')) as prog_lang, COUNT(*) as occurences
            FROM results_{year}
            GROUP BY 1
            ORDER BY 2
            DESC
            LIMIT {country_amount}
            ) as f
        ) || ' bigint';
    sql_text := 
        'SELECT *
            FROM crosstab(
            ''SELECT "Country" as country, unnest(string_to_array("LanguageHaveWorkedWith", '''';'''')) as prog_lang, COUNT("Country") as occurences
            FROM results_{year}
            GROUP BY 1,2'')
            AS ct(' || top_lang_column_definition_text || ')';
    OPEN _cursor FOR EXECUTE sql_text;
END $$;
FETCH ALL FROM _cursor;
"""     
with engine.connect() as con:
    result = con.execute(text(query))
    print(tuple(result.keys()))
    print("---")
    for row in result:
        print(row)
# Out:
# ('Country', 'JavaScript', 'HTML/CSS', 'Python')
# ---
# ('Afghanistan', 11, 12, 17)
# ('Albania', 3, 2, 5)
# ('Algeria', 1, 5, 7)
# ('Andorra', 1, 2, 3)
# ('Angola', 2, 1, 6)
# ('Argentina', 2, 28, 127)
# ('Armenia', 1, 2, 12)
# ('Australia', 5, 71, 534)
# ('Austria', 2, 51, 269)
# ('Azerbaijan', 3, 12, 18)
# ('Bahamas', 2, 2, 1)
# ('Bahrain', 2, 4, 4)
# ('Bangladesh', 12, 45, 90)
# ('Barbados', 1, 1, 2)
# ('Belarus', 6, 33, 18)
# ('Belgium', 4, 52, 214)
# ('Belize', 2, 1, 3)
# ('Benin', 2, 1, 1)
# ('Bhutan', 1, 1, 1)
# ('Bolivia', 1, 1, 6)
# ('Bosnia and Herzegovina', 6, 26, 26)
# ('Botswana', 1, 1, 2)
# ('Brazil', 12, 72, 496)
# ('Brunei Darussalam', 1, 1, 1)
# ('Bulgaria', 13, 91, 47)
# ('Burkina Faso', 2, 1, 1)
# ('Burundi', 1, 3, 2)
# ("C̫te d'Ivoire", 3, 3, 4)
# ('Cambodia', 5, 3, 5)
# ('Cameroon', 1, 3, 6)
# ('Canada', 21, 191, 986)
# ('Cape Verde', 1, 1, 1)
# ('Central African Republic', 1, 2, 1)
# ('Chad', 1, 1, 1)
# ('Chile', 2, 14, 54)
# ('China', 12, 54, 209)
# ('Colombia', 16, 53, 40)
# ('Congo, Republic of the...', 2, 1, 3)
# ('Costa Rica', 1, 7, 23)
# ('Croatia', 20, 63, 63)
# ('Cuba', 2, 7, 2)
# ('Cyprus', 1, 2, 9)
# ('Czech Republic', 1, 42, 254)
# ('Democratic Republic of the Congo', 1, 4, 2)
# ('Denmark', 11, 26, 200)
# ('Djibouti', 1, 1, 1)
# ('Dominica', 1, 1, 1)
# ('Dominican Republic', 2, 12, 11)
# ('Ecuador', 1, 13, 17)
# ('Egypt', 9, 36, 59)
# ('El Salvador', 1, 9, 4)
# ('Estonia', 5, 35, 18)
# ('Ethiopia', 1, 5, 4)
# ('Fiji', 1, 1, 1)
# ('Finland', 17, 178, 90)
# ('France', 8, 218, 994)
# ('Gambia', 1, 1, 1)
# ('Georgia', 3, 5, 22)
# ('Germany', 25, 373, 1895)
# ('Ghana', 2, 2, 13)
# ('Greece', 1, 54, 129)
# ('Guatemala', 1, 1, 14)
# ('Guinea', 2, 2, 2)
# ('Guyana', 2, 2, 1)
# ('Haiti', 1, 1, 3)
# ('Honduras', 5, 2, 11)
# ('Hong Kong (S.A.R.)', 1, 9, 55)
# ('Hungary', 29, 127, 90)
# ('Iceland', 1, 11, 4)
# ('India', 43, 379, 1483)
# ('Indonesia', 6, 20, 81)
# ('Iran, Islamic Republic of...', 3, 49, 147)
# ('Iraq', 2, 10, 10)
# ('Ireland', 1, 15, 120)
# ('Isle of Man', 2, 3, 2)
# ('Israel', 4, 78, 254)
# ('Italy', 7, 178, 490)
# ('Jamaica', 2, 3, 5)
# ('Japan', 3, 21, 118)
# ('Jordan', 1, 6, 6)
# ('Kazakhstan', 5, 4, 12)
# ('Kenya', 4, 9, 31)
# ('Kosovo', 1, 4, 2)
# ('Kuwait', 2, 2, 8)
# ('Kyrgyzstan', 2, 1, 1)
# ("Lao People's Democratic Republic", 1, 1, 2)
# ('Latvia', 1, 3, 25)
# ('Lebanon', 12, 21, 28)
# ('Lesotho', 1, 1, 3)
# ('Liberia', 2, 2, 2)
# ('Libyan Arab Jamahiriya', 1, 2, 3)
# ('Liechtenstein', 1, 1, 1)
# ('Lithuania', 1, 6, 48)
# ('Luxembourg', 1, 13, 8)
# ('Madagascar', 1, 4, 3)
# ('Malawi', 1, 1, 4)
# ('Malaysia', 16, 29, 66)
# ('Maldives', 1, 1, 5)
# ('Mali', 1, 1, 1)
# ('Malta', 1, 1, 4)
# ('Mauritania', 1, 2, 1)
# ('Mauritius', 7, 5, 12)
# ('Mexico', 2, 40, 119)
# ('Micronesia, Federated States of...', 1, 2, 2)
# ('Monaco', 1, 1, 1)
# ('Mongolia', 3, 6, 4)
# ('Montenegro', 1, 1, 5)
# ('Morocco', 3, 21, 33)
# ('Mozambique', 1, 2, 2)
# ('Myanmar', 5, 2, 1)
# ('Namibia', 1, 7, 3)
# ('Nepal', 1, 9, 32)
# ('Netherlands', 5, 70, 504)
# ('New Zealand', 1, 16, 160)
# ('Nicaragua', 2, 1, 1)
# ('Niger', 1, 1, 1)
# ('Nigeria', 11, 10, 25)
# ('Nomadic', 5, 8, 18)
# ('North Korea', 2, 2, 2)
# ('Norway', 4, 23, 172)
# ('Oman', 1, 2, 1)
# ('Pakistan', 5, 72, 86)
# ('Palestine', 3, 3, 6)
# ('Panama', 2, 2, 12)
# ('Papua New Guinea', 1, None, None)
# ('Paraguay', 1, 8, 6)
# ('Peru', 1, 9, 30)
# ('Philippines', 7, 27, 67)
# ('Poland', 3, 101, 520)
# ('Portugal', 4, 53, 131)
# ('Qatar', 6, 4, 8)
# ('Republic of Korea', 1, 2, 8)
# ('Republic of Moldova', 1, 1, 5)
# ('Romania', 2, 34, 135)
# ('Russian Federation', 7, 94, 417)
# ('Rwanda', 6, 6, 6)
# ('Saint Kitts and Nevis', 1, 1, 1)
# ('Saint Lucia', 1, 1, 1)
# ('Saint Vincent and the Grenadines', 1, 1, None)
# ('San Marino', 1, 1, 1)
# ('Saudi Arabia', 2, 8, 22)
# ('Senegal', 1, 3, 7)
# ('Serbia', 23, 63, 66)
# ('Sierra Leone', 1, 1, 1)
# ('Singapore', 22, 79, 55)
# ('Slovakia', 1, 21, 61)
# ('Slovenia', 18, 58, 63)
# ('Somalia', 1, 1, 1)
# ('South Africa', 2, 10, 144)
# ('South Korea', 3, 9, 35)
# ('Spain', 1, 71, 434)
# ('Sri Lanka', 1, 9, 48)
# ('Sudan', 1, 7, 5)
# ('Suriname', 1, 1, 2)
# ('Swaziland', 1, 5, 1)
# ('Sweden', 7, 65, 399)
# ('Switzerland', 2, 51, 331)
# ('Syrian Arab Republic', 1, 2, 3)
# ('Taiwan', 2, 13, 73)
# ('Tajikistan', 1, 1, 1)
# ('Thailand', 9, 16, 51)
# ('The former Yugoslav Republic of Macedonia', 5, 9, 9)
# ('Togo', 3, 2, 1)
# ('Trinidad and Tobago', 1, 1, 6)
# ('Tunisia', 1, 17, 32)
# ('Turkey', 12, 88, 169)
# ('Turkmenistan', 3, 3, 5)
# ('Tuvalu', 1, 1, 1)
# ('Uganda', 1, 4, 11)
# ('Ukraine', 6, 40, 175)
# ('United Arab Emirates', 6, 8, 27)
# ('United Kingdom of Great Britain and Northern Ireland', 27, 212, 1396)
# ('United Republic of Tanzania', 1, 3, 10)
# ('United States of America', 112, 916, 5757)
# ('Uruguay', 3, 28, 15)
# ('Uzbekistan', 2, 3, 13)
# ('Venezuela, Bolivarian Republic of...', 1, 5, 19)
# ('Viet Nam', 2, 27, 69)
# ('Yemen', 1, 2, 11)
# ('Zambia', 1, 5, 5)
# ('Zimbabwe', 1, 1, 6)
